# %%
import pytesseract
from pytesseract import image_to_string
from PIL import Image

# %%
import os

# %%
os.chdir('C:\\Users\\AJAY\\Documents\\Python Code Practise')

# %%
imgpath = 'Capture.jpg'

# %%
image = Image.open(imgpath)

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=662x424 at 0x208B770D780>

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files (x86)\Tesseract-OCR\tesseract.exe"
text = pytesseract.image_to_string(image)

# %%
print(text)
# Out:
# protuced tron péprassactionsotiticationcer tile of 12/00/2059
#
# cree trom the toput resort
#
# fera casszonan
# vietnam dom
# woase meson
#
# pare or nmn
# ataree
#
# osisi/nte cvicouce
#
# death States
# tncseacce mater
# Airers tine 1 exe sso
# Aarece cine a
#
# time 3
#
# aise a x
#
# Antran time a Kow
# yore coon a
#
# Beate mate
#
# gener aree
#
# wail tasterton tea wor
# ese viene ro P
#
# Rose Exclusion ma kemmos
# wbile more to rome
#
# wanita rome Exetuston toa
# nals addvere
#
# Email Eectunion ma :
# Valse - evans rmcine ino
# ramas «
# gees so mo :
# Previous rranmetion type
#
# easeaction utfeccive ince
# nate
#
# Change or adviser
# iits
# Oraganizetion wane wmw vaiue ~erercut rommmne tan ans oro
